# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /gdrive
# /gdrive

# %%
ls
# Out:
# 'My Drive'/

# %%
cd 'My Drive'
# Out:
# /gdrive/My Drive

# %%
cd DEPSTAR/Subject/CSE\ Machine\ Learning
# Out:
# /gdrive/My Drive/DEPSTAR/Subject/CSE Machine Learning

# %%
ls
# Out:
# 'Faculty Practical Work'/   Material/
# 'Lab Work'/                'Student Practical Data.gsheet'

# %%
cd Faculty\ Practical\ Work
# Out:
# /gdrive/My Drive/DEPSTAR/Subject/CSE Machine Learning/Faculty Practical Work

# %%
cd Practical\ 1
# Out:
# /gdrive/My Drive/DEPSTAR/Subject/CSE Machine Learning/Faculty Practical Work/Practical 1

# %%
ls
# Out:
# iris.csv  MLCS344First.ipynb  timesData.csv

# %%
df = pd.read_csv('timesData.csv')

# %%
df
# Out:
#      world_rank                        university_name  ... female_male_ratio  year
# 0             1                     Harvard University  ...               NaN  2011
# 1             2     California Institute of Technology  ...           33 : 67  2011
# 2             3  Massachusetts Institute of Technology  ...           37 : 63  2011
# 3             4                    Stanford University  ...           42 : 58  2011
# 4             5                   Princeton University  ...           45 : 55  2011
# ...         ...                                    ...  ...               ...   ...
# 2598    601-800                    Yeungnam University  ...           48 : 52  2016
# 2599    601-800            Yıldız Technical University  ...           36 : 64  2016
# 2600    601-800               Yokohama City University  ...               NaN  2016
# 2601    601-800           Yokohama National University  ...           28 : 72  2016
# ...

# %%
df.head(8)
# Out:
#   world_rank                        university_name  ... female_male_ratio  year
# 0          1                     Harvard University  ...               NaN  2011
# 1          2     California Institute of Technology  ...           33 : 67  2011
# 2          3  Massachusetts Institute of Technology  ...           37 : 63  2011
# 3          4                    Stanford University  ...           42 : 58  2011
# 4          5                   Princeton University  ...           45 : 55  2011
# 5          6                University of Cambridge  ...           46 : 54  2011
# 6          6                   University of Oxford  ...           46 : 54  2011
# 7          8     University of California, Berkeley  ...           50 : 50  2011
#
# [8 rows x 14 columns]

# %%
df.tail(7)
# Out:
#      world_rank               university_name  ... female_male_ratio  year
# 2596    601-800     University of Westminster  ...           57 : 43  2016
# 2597    601-800             Xidian University  ...           29 : 71  2016
# 2598    601-800           Yeungnam University  ...           48 : 52  2016
# 2599    601-800   Yıldız Technical University  ...           36 : 64  2016
# 2600    601-800      Yokohama City University  ...               NaN  2016
# 2601    601-800  Yokohama National University  ...           28 : 72  2016
# 2602    601-800            Yuan Ze University  ...           43 : 57  2016
#
# [7 rows x 14 columns]

# %%
new_df =df.dropna()
new_df
# Out:
#      world_rank                        university_name  ... female_male_ratio  year
# 1             2     California Institute of Technology  ...           33 : 67  2011
# 2             3  Massachusetts Institute of Technology  ...           37 : 63  2011
# 3             4                    Stanford University  ...           42 : 58  2011
# 4             5                   Princeton University  ...           45 : 55  2011
# 5             6                University of Cambridge  ...           46 : 54  2011
# ...         ...                                    ...  ...               ...   ...
# 2597    601-800                      Xidian University  ...           29 : 71  2016
# 2598    601-800                    Yeungnam University  ...           48 : 52  2016
# 2599    601-800            Yıldız Technical University  ...           36 : 64  2016
# 2601    601-800           Yokohama National University  ...           28 : 72  2016
# ...

# %%
new_df.replace(to_replace="-", value=np.NaN, inplace=True)
new_df
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:4278: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,
#      world_rank                        university_name  ... female_male_ratio  year
# 1             2     California Institute of Technology  ...           33 : 67  2011
# 2             3  Massachusetts Institute of Technology  ...           37 : 63  2011
# 3             4                    Stanford University  ...           42 : 58  2011
# 4             5                   Princeton University  ...           45 : 55  2011
# 5             6                University of Cambridge  ...           46 : 54  2011
# ...         ...                                    ...  ...               ...   ...
# ...

# %%
new_df.fillna(method="ffill", inplace=True)
new_df
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:4259: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   **kwargs
#      world_rank                        university_name  ... female_male_ratio  year
# 1             2     California Institute of Technology  ...           33 : 67  2011
# 2             3  Massachusetts Institute of Technology  ...           37 : 63  2011
# 3             4                    Stanford University  ...           42 : 58  2011
# 4             5                   Princeton University  ...           45 : 55  2011
# 5             6                University of Cambridge  ...           46 : 54  2011
# ...         ...                                    ...  ...               ...   ...
# ...

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
new_df.corr()
# Out:
#                      teaching  research  ...  student_staff_ratio      year
# teaching             1.000000  0.913656  ...            -0.280385 -0.279468
# research             0.913656  1.000000  ...            -0.196472 -0.278592
# citations            0.510993  0.527020  ...            -0.142686 -0.175293
# student_staff_ratio -0.280385 -0.196472  ...             1.000000  0.061974
# year                -0.279468 -0.278592  ...             0.061974  1.000000
#
# [5 rows x 5 columns]

# %%
import seaborn as sn
corrMatrix = new_df.corr()
sn.heatmap(corrMatrix, annot=True)

# %%
plt.hist(new_df['total_score'], color='#0504aa', alpha=0.7, bins=5)
plt.xticks(np.arange(1.0,500.0, step=50))
plt.title('Total Score Histogram',fontsize=15)
plt.show()

# %%
new_df['total_score'].dtype
# Out:
# dtype('O')

# %%
new_df[['total_score']] = new_df[['total_score']].apply(pd.to_numeric)
new_df['total_score'].dtype

#  new_df['total_score'].astype(int)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:3509: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# dtype('float64')

# %%
idf = pd.read_csv('iris.csv')

# %%
idf.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
plt.scatter(idf['sepal.length'], idf['sepal.width'], marker='o')
plt.show()

# %%
sn.boxplot(x='petal.length', y='variety', data=idf)

# %%
plt.hist(idf['sepal.width'], alpha=0.7, bins=5)
plt.show()

# %%
plt.hist(idf['sepal.width'], alpha=0.7, bins=10)
plt.show()
